# %%
from sklearn.neural_network import MLPClassifier
import pickle
import numpy as np

feature_path = "/data/ahngeo11/TimeSformer/outputs/timesformer-k400-kth-fe-8f.pkl"
with open(feature_path, 'rb') as f :
    data = pickle.load(f)
    
label_path = "/data/ahngeo11/svt/datasets/annotations/kth_fe_videos.txt"
with open(label_path, 'r') as f :
    label = f.readlines()
    label = [label[i].strip('\n').split()[1] for i in range(len(label))]

data = np.array(data)
label = np.array(label)

print("data shape : ", data.shape)
print("label shape : ", label.shape)
# Out:
# data shape :  (599, 768)
# label shape :  (599,)

# %%
label
# Out:
# array(['boxing/person01_boxing_d1.avi 0\n',
#        'boxing/person01_boxing_d2.avi 0\n',
#        'boxing/person01_boxing_d3.avi 0\n',
#        'boxing/person01_boxing_d4.avi 0\n',
#        'boxing/person02_boxing_d1.avi 0\n',
#        'boxing/person02_boxing_d2.avi 0\n',
#        'boxing/person02_boxing_d3.avi 0\n',
#        'boxing/person02_boxing_d4.avi 0\n',
#        'boxing/person03_boxing_d1.avi 0\n',
#        'boxing/person03_boxing_d2.avi 0\n',
#        'boxing/person03_boxing_d3.avi 0\n',
#        'boxing/person03_boxing_d4.avi 0\n',
#        'boxing/person04_boxing_d1.avi 0\n',
#        'boxing/person04_boxing_d2.avi 0\n',
#        'boxing/person04_boxing_d3.avi 0\n',
#        'boxing/person04_boxing_d4.avi 0\n',
#        'boxing/person05_boxing_d1.avi 0\n',
#        'boxing/person05_boxing_d2.avi 0\n',
#        'boxing/person05_boxing_d3.avi 0\n',
#        'boxing/person05_boxing_d4.avi 0\n',
#        'boxing/person06_boxing_d1.avi 0\n',
#        'boxing/person06_boxing_d2.avi 0\n',
#        'boxing/person06_boxing_d3.avi 0\n',
#        'boxing/person06_boxing_d4.avi 0\n',
#        'boxing/person07_boxing_d1.avi 0\n',
#        'boxing/person07_boxing_d2.avi 0\n',
#        'boxing/person07_boxing_d3.avi 0\n',
#        'boxing/person07_boxing_d4.avi 0\n',
#        'boxing/person08_boxing_d1.avi 0\n',
#        'boxing/person08_boxing_d2.avi 0\n',
#        'boxing/person08_boxing_d3.avi 0\n',
#        'boxing/person08_boxing_d4.avi 0\n',
#        'boxing/person09_boxing_d1.avi 0\n',
#        'boxing/person09_boxing_d2.avi 0\n',
#        'boxing/person09_boxing_d3.avi 0\n',
#        'boxing/person09_boxing_d4.avi 0\n',
#        'boxing/person10_boxing_d1.avi 0\n',
#        'boxing/person10_boxing_d2.avi 0\n',
#        'boxing/person10_boxing_d3.avi 0\n',
#        'boxing/person10_boxing_d4.avi 0\n',
#        'boxing/person11_boxing_d1.avi 0\n',
#        'boxing/person11_boxing_d2.avi 0\n',
#        'boxing/person11_boxing_d3.avi 0\n',
#        'boxing/person11_boxing_d4.avi 0\n',
#        'boxing/person12_boxing_d1.avi 0\n',
#        'boxing/person12_boxing_d2.avi 0\n',
#        'boxing/person12_boxing_d3.avi 0\n',
#        'boxing/person12_boxing_d4.avi 0\n',
#        'boxing/person13_boxing_d1.avi 0\n',
#        'boxing/person13_boxing_d2.avi 0\n',
#        'boxing/person13_boxing_d3.avi 0\n',
#        'boxing/person13_boxing_d4.avi 0\n',
#        'boxing/person14_boxing_d1.avi 0\n',
#        'boxing/person14_boxing_d2.avi 0\n',
#        'boxing/person14_boxing_d3.avi 0\n',
#        'boxing/person14_boxing_d4.avi 0\n',
#        'boxing/person15_boxing_d1.avi 0\n',
#        'boxing/person15_boxing_d2.avi 0\n',
#        'boxing/person15_boxing_d3.avi 0\n',
#        'boxing/person15_boxing_d4.avi 0\n',
#        'boxing/person16_boxing_d1.avi 0\n',
#        'boxing/person16_boxing_d2.avi 0\n',
#        'boxing/person16_boxing_d3.avi 0\n',
#        'boxing/person16_boxing_d4.avi 0\n',
#        'boxing/person17_boxing_d1.avi 0\n',
#        'boxing/person17_boxing_d2.avi 0\n',
#        'boxing/person17_boxing_d3.avi 0\n',
#        'boxing/person17_boxing_d4.avi 0\n',
#        'boxing/person18_boxing_d1.avi 0\n',
#        'boxing/person18_boxing_d2.avi 0\n',
#        'boxing/person18_boxing_d3.avi 0\n',
#        'boxing/person18_boxing_d4.avi 0\n',
#        'boxing/person19_boxing_d1.avi 0\n',
#        'boxing/person19_boxing_d2.avi 0\n',
#        'boxing/person19_boxing_d3.avi 0\n',
#        'boxing/person19_boxing_d4.avi 0\n',
#        'boxing/person20_boxing_d1.avi 0\n',
#        'boxing/person20_boxing_d2.avi 0\n',
#        'boxing/person20_boxing_d3.avi 0\n',
#        'boxing/person20_boxing_d4.avi 0\n',
#        'boxing/person21_boxing_d1.avi 0\n',
#        'boxing/person21_boxing_d2.avi 0\n',
#        'boxing/person21_boxing_d3.avi 0\n',
#        'boxing/person21_boxing_d4.avi 0\n',
#        'boxing/person22_boxing_d1.avi 0\n',
#        'boxing/person22_boxing_d2.avi 0\n',
#        'boxing/person22_boxing_d3.avi 0\n',
#        'boxing/person22_boxing_d4.avi 0\n',
#        'boxing/person23_boxing_d1.avi 0\n',
#        'boxing/person23_boxing_d2.avi 0\n',
#        'boxing/person23_boxing_d3.avi 0\n',
#        'boxing/person23_boxing_d4.avi 0\n',
#        'boxing/person24_boxing_d1.avi 0\n',
#        'boxing/person24_boxing_d2.avi 0\n',
#        'boxing/person24_boxing_d3.avi 0\n',
#        'boxing/person24_boxing_d4.avi 0\n',
#        'boxing/person25_boxing_d1.avi 0\n',
#        'boxing/person25_boxing_d2.avi 0\n',
#        'boxing/person25_boxing_d3.avi 0\n',
#        'boxing/person25_boxing_d4.avi 0\n',
#        'handclapping/person01_handclapping_d1.avi 1\n',
#        'handclapping/person01_handclapping_d2.avi 1\n',
#        'handclapping/person01_handclapping_d3.avi 1\n',
#        'handclapping/person01_handclapping_d4.avi 1\n',
#        'handclapping/person02_handclapping_d1.avi 1\n',
#        'handclapping/person02_handclapping_d2.avi 1\n',
#        'handclapping/person02_handclapping_d3.avi 1\n',
#        'handclapping/person02_handclapping_d4.avi 1\n',
#        'handclapping/person03_handclapping_d1.avi 1\n',
#        'handclapping/person03_handclapping_d2.avi 1\n',
#        'handclapping/person03_handclapping_d3.avi 1\n',
#        'handclapping/person03_handclapping_d4.avi 1\n',
#        'handclapping/person04_handclapping_d1.avi 1\n',
#        'handclapping/person04_handclapping_d2.avi 1\n',
#        'handclapping/person04_handclapping_d3.avi 1\n',
#        'handclapping/person04_handclapping_d4.avi 1\n',
#        'handclapping/person05_handclapping_d1.avi 1\n',
#        'handclapping/person05_handclapping_d2.avi 1\n',
#        'handclapping/person05_handclapping_d3.avi 1\n',
#        'handclapping/person05_handclapping_d4.avi 1\n',
#        'handclapping/person06_handclapping_d1.avi 1\n',
#        'handclapping/person06_handclapping_d2.avi 1\n',
#        'handclapping/person06_handclapping_d3.avi 1\n',
#        'handclapping/person06_handclapping_d4.avi 1\n',
#        'handclapping/person07_handclapping_d1.avi 1\n',
#        'handclapping/person07_handclapping_d2.avi 1\n',
#        'handclapping/person07_handclapping_d3.avi 1\n',
#        'handclapping/person07_handclapping_d4.avi 1\n',
#        'handclapping/person08_handclapping_d1.avi 1\n',
#        'handclapping/person08_handclapping_d2.avi 1\n',
#        'handclapping/person08_handclapping_d3.avi 1\n',
#        'handclapping/person08_handclapping_d4.avi 1\n',
#        'handclapping/person09_handclapping_d1.avi 1\n',
#        'handclapping/person09_handclapping_d2.avi 1\n',
#        'handclapping/person09_handclapping_d3.avi 1\n',
#        'handclapping/person09_handclapping_d4.avi 1\n',
#        'handclapping/person10_handclapping_d1.avi 1\n',
#        'handclapping/person10_handclapping_d2.avi 1\n',
#        'handclapping/person10_handclapping_d3.avi 1\n',
#        'handclapping/person10_handclapping_d4.avi 1\n',
#        'handclapping/person11_handclapping_d1.avi 1\n',
#        'handclapping/person11_handclapping_d2.avi 1\n',
#        'handclapping/person11_handclapping_d3.avi 1\n',
#        'handclapping/person11_handclapping_d4.avi 1\n',
#        'handclapping/person12_handclapping_d1.avi 1\n',
#        'handclapping/person12_handclapping_d2.avi 1\n',
#        'handclapping/person12_handclapping_d3.avi 1\n',
#        'handclapping/person12_handclapping_d4.avi 1\n',
#        'handclapping/person13_handclapping_d1.avi 1\n',
#        'handclapping/person13_handclapping_d2.avi 1\n',
#        'handclapping/person13_handclapping_d4.avi 1\n',
#        'handclapping/person14_handclapping_d1.avi 1\n',
#        'handclapping/person14_handclapping_d2.avi 1\n',
#        'handclapping/person14_handclapping_d3.avi 1\n',
#        'handclapping/person14_handclapping_d4.avi 1\n',
#        'handclapping/person15_handclapping_d1.avi 1\n',
#        'handclapping/person15_handclapping_d2.avi 1\n',
#        'handclapping/person15_handclapping_d3.avi 1\n',
#        'handclapping/person15_handclapping_d4.avi 1\n',
#        'handclapping/person16_handclapping_d1.avi 1\n',
#        'handclapping/person16_handclapping_d2.avi 1\n',
#        'handclapping/person16_handclapping_d3.avi 1\n',
#        'handclapping/person16_handclapping_d4.avi 1\n',
#        'handclapping/person17_handclapping_d1.avi 1\n',
#        'handclapping/person17_handclapping_d2.avi 1\n',
#        'handclapping/person17_handclapping_d3.avi 1\n',
#        'handclapping/person17_handclapping_d4.avi 1\n',
#        'handclapping/person18_handclapping_d1.avi 1\n',
#        'handclapping/person18_handclapping_d2.avi 1\n',
#        'handclapping/person18_handclapping_d3.avi 1\n',
#        'handclapping/person18_handclapping_d4.avi 1\n',
#        'handclapping/person19_handclapping_d1.avi 1\n',
#        'handclapping/person19_handclapping_d2.avi 1\n',
#        'handclapping/person19_handclapping_d3.avi 1\n',
#        'handclapping/person19_handclapping_d4.avi 1\n',
#        'handclapping/person20_handclapping_d1.avi 1\n',
#        'handclapping/person20_handclapping_d2.avi 1\n',
#        'handclapping/person20_handclapping_d3.avi 1\n',
#        'handclapping/person20_handclapping_d4.avi 1\n',
#        'handclapping/person21_handclapping_d1.avi 1\n',
#        'handclapping/person21_handclapping_d2.avi 1\n',
#        'handclapping/person21_handclapping_d3.avi 1\n',
#        'handclapping/person21_handclapping_d4.avi 1\n',
#        'handclapping/person22_handclapping_d1.avi 1\n',
#        'handclapping/person22_handclapping_d2.avi 1\n',
#        'handclapping/person22_handclapping_d3.avi 1\n',
#        'handclapping/person22_handclapping_d4.avi 1\n',
#        'handclapping/person23_handclapping_d1.avi 1\n',
#        'handclapping/person23_handclapping_d2.avi 1\n',
#        'handclapping/person23_handclapping_d3.avi 1\n',
#        'handclapping/person23_handclapping_d4.avi 1\n',
#        'handclapping/person24_handclapping_d1.avi 1\n',
#        'handclapping/person24_handclapping_d2.avi 1\n',
#        'handclapping/person24_handclapping_d3.avi 1\n',
#        'handclapping/person24_handclapping_d4.avi 1\n',
#        'handclapping/person25_handclapping_d1.avi 1\n',
#        'handclapping/person25_handclapping_d2.avi 1\n',
#        'handclapping/person25_handclapping_d3.avi 1\n',
#        'handclapping/person25_handclapping_d4.avi 1\n',
#        'handwaving/person01_handwaving_d1.avi 2\n',
#        'handwaving/person01_handwaving_d2.avi 2\n',
#        'handwaving/person01_handwaving_d3.avi 2\n',
#        'handwaving/person01_handwaving_d4.avi 2\n',
#        'handwaving/person02_handwaving_d1.avi 2\n',
#        'handwaving/person02_handwaving_d2.avi 2\n',
#        'handwaving/person02_handwaving_d3.avi 2\n',
#        'handwaving/person02_handwaving_d4.avi 2\n',
#        'handwaving/person03_handwaving_d1.avi 2\n',
#        'handwaving/person03_handwaving_d2.avi 2\n',
#        'handwaving/person03_handwaving_d3.avi 2\n',
#        'handwaving/person03_handwaving_d4.avi 2\n',
#        'handwaving/person04_handwaving_d1.avi 2\n',
#        'handwaving/person04_handwaving_d2.avi 2\n',
#        'handwaving/person04_handwaving_d3.avi 2\n',
#        'handwaving/person04_handwaving_d4.avi 2\n',
#        'handwaving/person05_handwaving_d1.avi 2\n',
#        'handwaving/person05_handwaving_d2.avi 2\n',
#        'handwaving/person05_handwaving_d3.avi 2\n',
#        'handwaving/person05_handwaving_d4.avi 2\n',
#        'handwaving/person06_handwaving_d1.avi 2\n',
#        'handwaving/person06_handwaving_d2.avi 2\n',
#        'handwaving/person06_handwaving_d3.avi 2\n',
#        'handwaving/person06_handwaving_d4.avi 2\n',
#        'handwaving/person07_handwaving_d1.avi 2\n',
#        'handwaving/person07_handwaving_d2.avi 2\n',
#        'handwaving/person07_handwaving_d3.avi 2\n',
#        'handwaving/person07_handwaving_d4.avi 2\n',
#        'handwaving/person08_handwaving_d1.avi 2\n',
#        'handwaving/person08_handwaving_d2.avi 2\n',
#        'handwaving/person08_handwaving_d3.avi 2\n',
#        'handwaving/person08_handwaving_d4.avi 2\n',
#        'handwaving/person09_handwaving_d1.avi 2\n',
#        'handwaving/person09_handwaving_d2.avi 2\n',
#        'handwaving/person09_handwaving_d3.avi 2\n',
#        'handwaving/person09_handwaving_d4.avi 2\n',
#        'handwaving/person10_handwaving_d1.avi 2\n',
#        'handwaving/person10_handwaving_d2.avi 2\n',
#        'handwaving/person10_handwaving_d3.avi 2\n',
#        'handwaving/person10_handwaving_d4.avi 2\n',
#        'handwaving/person11_handwaving_d1.avi 2\n',
#        'handwaving/person11_handwaving_d2.avi 2\n',
#        'handwaving/person11_handwaving_d3.avi 2\n',
#        'handwaving/person11_handwaving_d4.avi 2\n',
#        'handwaving/person12_handwaving_d1.avi 2\n',
#        'handwaving/person12_handwaving_d2.avi 2\n',
#        'handwaving/person12_handwaving_d3.avi 2\n',
#        'handwaving/person12_handwaving_d4.avi 2\n',
#        'handwaving/person13_handwaving_d1.avi 2\n',
#        'handwaving/person13_handwaving_d2.avi 2\n',
#        'handwaving/person13_handwaving_d3.avi 2\n',
#        'handwaving/person13_handwaving_d4.avi 2\n',
#        'handwaving/person14_handwaving_d1.avi 2\n',
#        'handwaving/person14_handwaving_d2.avi 2\n',
#        'handwaving/person14_handwaving_d3.avi 2\n',
#        'handwaving/person14_handwaving_d4.avi 2\n',
#        'handwaving/person15_handwaving_d1.avi 2\n',
#        'handwaving/person15_handwaving_d2.avi 2\n',
#        'handwaving/person15_handwaving_d3.avi 2\n',
#        'handwaving/person15_handwaving_d4.avi 2\n',
#        'handwaving/person16_handwaving_d1.avi 2\n',
#        'handwaving/person16_handwaving_d2.avi 2\n',
#        'handwaving/person16_handwaving_d3.avi 2\n',
#        'handwaving/person16_handwaving_d4.avi 2\n',
#        'handwaving/person17_handwaving_d1.avi 2\n',
#        'handwaving/person17_handwaving_d2.avi 2\n',
#        'handwaving/person17_handwaving_d3.avi 2\n',
#        'handwaving/person17_handwaving_d4.avi 2\n',
#        'handwaving/person18_handwaving_d1.avi 2\n',
#        'handwaving/person18_handwaving_d2.avi 2\n',
#        'handwaving/person18_handwaving_d3.avi 2\n',
#        'handwaving/person18_handwaving_d4.avi 2\n',
#        'handwaving/person19_handwaving_d1.avi 2\n',
#        'handwaving/person19_handwaving_d2.avi 2\n',
#        'handwaving/person19_handwaving_d3.avi 2\n',
#        'handwaving/person19_handwaving_d4.avi 2\n',
#        'handwaving/person20_handwaving_d1.avi 2\n',
#        'handwaving/person20_handwaving_d2.avi 2\n',
#        'handwaving/person20_handwaving_d3.avi 2\n',
#        'handwaving/person20_handwaving_d4.avi 2\n',
#        'handwaving/person21_handwaving_d1.avi 2\n',
#        'handwaving/person21_handwaving_d2.avi 2\n',
#        'handwaving/person21_handwaving_d3.avi 2\n',
#        'handwaving/person21_handwaving_d4.avi 2\n',
#        'handwaving/person22_handwaving_d1.avi 2\n',
#        'handwaving/person22_handwaving_d2.avi 2\n',
#        'handwaving/person22_handwaving_d3.avi 2\n',
#        'handwaving/person22_handwaving_d4.avi 2\n',
#        'handwaving/person23_handwaving_d1.avi 2\n',
#        'handwaving/person23_handwaving_d2.avi 2\n',
#        'handwaving/person23_handwaving_d3.avi 2\n',
#        'handwaving/person23_handwaving_d4.avi 2\n',
#        'handwaving/person24_handwaving_d1.avi 2\n',
#        'handwaving/person24_handwaving_d2.avi 2\n',
#        'handwaving/person24_handwaving_d3.avi 2\n',
#        'handwaving/person24_handwaving_d4.avi 2\n',
#        'handwaving/person25_handwaving_d1.avi 2\n',
#        'handwaving/person25_handwaving_d2.avi 2\n',
#        'handwaving/person25_handwaving_d3.avi 2\n',
#        'handwaving/person25_handwaving_d4.avi 2\n',
#        'jogging/person01_jogging_d1.avi 3\n',
#        'jogging/person01_jogging_d2.avi 3\n',
#        'jogging/person01_jogging_d3.avi 3\n',
#        'jogging/person01_jogging_d4.avi 3\n',
#        'jogging/person02_jogging_d1.avi 3\n',
#        'jogging/person02_jogging_d2.avi 3\n',
#        'jogging/person02_jogging_d3.avi 3\n',
#        'jogging/person02_jogging_d4.avi 3\n',
#        'jogging/person03_jogging_d1.avi 3\n',
#        'jogging/person03_jogging_d2.avi 3\n',
#        'jogging/person03_jogging_d3.avi 3\n',
#        'jogging/person03_jogging_d4.avi 3\n',
#        'jogging/person04_jogging_d1.avi 3\n',
#        'jogging/person04_jogging_d2.avi 3\n',
#        'jogging/person04_jogging_d3.avi 3\n',
#        'jogging/person04_jogging_d4.avi 3\n',
#        'jogging/person05_jogging_d1.avi 3\n',
#        'jogging/person05_jogging_d2.avi 3\n',
#        'jogging/person05_jogging_d3.avi 3\n',
#        'jogging/person05_jogging_d4.avi 3\n',
#        'jogging/person06_jogging_d1.avi 3\n',
#        'jogging/person06_jogging_d2.avi 3\n',
#        'jogging/person06_jogging_d3.avi 3\n',
#        'jogging/person06_jogging_d4.avi 3\n',
#        'jogging/person07_jogging_d1.avi 3\n',
#        'jogging/person07_jogging_d2.avi 3\n',
#        'jogging/person07_jogging_d3.avi 3\n',
#        'jogging/person07_jogging_d4.avi 3\n',
#        'jogging/person08_jogging_d1.avi 3\n',
#        'jogging/person08_jogging_d2.avi 3\n',
#        'jogging/person08_jogging_d3.avi 3\n',
#        'jogging/person08_jogging_d4.avi 3\n',
#        'jogging/person09_jogging_d1.avi 3\n',
#        'jogging/person09_jogging_d2.avi 3\n',
#        'jogging/person09_jogging_d3.avi 3\n',
#        'jogging/person09_jogging_d4.avi 3\n',
#        'jogging/person10_jogging_d1.avi 3\n',
#        'jogging/person10_jogging_d2.avi 3\n',
#        'jogging/person10_jogging_d3.avi 3\n',
#        'jogging/person10_jogging_d4.avi 3\n',
#        'jogging/person11_jogging_d1.avi 3\n',
#        'jogging/person11_jogging_d2.avi 3\n',
#        'jogging/person11_jogging_d3.avi 3\n',
#        'jogging/person11_jogging_d4.avi 3\n',
#        'jogging/person12_jogging_d1.avi 3\n',
#        'jogging/person12_jogging_d2.avi 3\n',
#        'jogging/person12_jogging_d3.avi 3\n',
#        'jogging/person12_jogging_d4.avi 3\n',
#        'jogging/person13_jogging_d1.avi 3\n',
#        'jogging/person13_jogging_d2.avi 3\n',
#        'jogging/person13_jogging_d3.avi 3\n',
#        'jogging/person13_jogging_d4.avi 3\n',
#        'jogging/person14_jogging_d1.avi 3\n',
#        'jogging/person14_jogging_d2.avi 3\n',
#        'jogging/person14_jogging_d3.avi 3\n',
#        'jogging/person14_jogging_d4.avi 3\n',
#        'jogging/person15_jogging_d1.avi 3\n',
#        'jogging/person15_jogging_d2.avi 3\n',
#        'jogging/person15_jogging_d3.avi 3\n',
#        'jogging/person15_jogging_d4.avi 3\n',
#        'jogging/person16_jogging_d1.avi 3\n',
#        'jogging/person16_jogging_d2.avi 3\n',
#        'jogging/person16_jogging_d3.avi 3\n',
#        'jogging/person16_jogging_d4.avi 3\n',
#        'jogging/person17_jogging_d1.avi 3\n',
#        'jogging/person17_jogging_d2.avi 3\n',
#        'jogging/person17_jogging_d3.avi 3\n',
#        'jogging/person17_jogging_d4.avi 3\n',
#        'jogging/person18_jogging_d1.avi 3\n',
#        'jogging/person18_jogging_d2.avi 3\n',
#        'jogging/person18_jogging_d3.avi 3\n',
#        'jogging/person18_jogging_d4.avi 3\n',
#        'jogging/person19_jogging_d1.avi 3\n',
#        'jogging/person19_jogging_d2.avi 3\n',
#        'jogging/person19_jogging_d3.avi 3\n',
#        'jogging/person19_jogging_d4.avi 3\n',
#        'jogging/person20_jogging_d1.avi 3\n',
#        'jogging/person20_jogging_d2.avi 3\n',
#        'jogging/person20_jogging_d3.avi 3\n',
#        'jogging/person20_jogging_d4.avi 3\n',
#        'jogging/person21_jogging_d1.avi 3\n',
#        'jogging/person21_jogging_d2.avi 3\n',
#        'jogging/person21_jogging_d3.avi 3\n',
#        'jogging/person21_jogging_d4.avi 3\n',
#        'jogging/person22_jogging_d1.avi 3\n',
#        'jogging/person22_jogging_d2.avi 3\n',
#        'jogging/person22_jogging_d3.avi 3\n',
#        'jogging/person22_jogging_d4.avi 3\n',
#        'jogging/person23_jogging_d1.avi 3\n',
#        'jogging/person23_jogging_d2.avi 3\n',
#        'jogging/person23_jogging_d3.avi 3\n',
#        'jogging/person23_jogging_d4.avi 3\n',
#        'jogging/person24_jogging_d1.avi 3\n',
#        'jogging/person24_jogging_d2.avi 3\n',
#        'jogging/person24_jogging_d3.avi 3\n',
#        'jogging/person24_jogging_d4.avi 3\n',
#        'jogging/person25_jogging_d1.avi 3\n',
#        'jogging/person25_jogging_d2.avi 3\n',
#        'jogging/person25_jogging_d3.avi 3\n',
#        'jogging/person25_jogging_d4.avi 3\n',
#        'running/person01_running_d1.avi 4\n',
#        'running/person01_running_d2.avi 4\n',
#        'running/person01_running_d3.avi 4\n',
#        'running/person01_running_d4.avi 4\n',
#        'running/person02_running_d1.avi 4\n',
#        'running/person02_running_d2.avi 4\n',
#        'running/person02_running_d3.avi 4\n',
#        'running/person02_running_d4.avi 4\n',
#        'running/person03_running_d1.avi 4\n',
#        'running/person03_running_d2.avi 4\n',
#        'running/person03_running_d3.avi 4\n',
#        'running/person03_running_d4.avi 4\n',
#        'running/person04_running_d1.avi 4\n',
#        'running/person04_running_d2.avi 4\n',
#        'running/person04_running_d3.avi 4\n',
#        'running/person04_running_d4.avi 4\n',
#        'running/person05_running_d1.avi 4\n',
#        'running/person05_running_d2.avi 4\n',
#        'running/person05_running_d3.avi 4\n',
#        'running/person05_running_d4.avi 4\n',
#        'running/person06_running_d1.avi 4\n',
#        'running/person06_running_d2.avi 4\n',
#        'running/person06_running_d3.avi 4\n',
#        'running/person06_running_d4.avi 4\n',
#        'running/person07_running_d1.avi 4\n',
#        'running/person07_running_d2.avi 4\n',
#        'running/person07_running_d3.avi 4\n',
#        'running/person07_running_d4.avi 4\n',
#        'running/person08_running_d1.avi 4\n',
#        'running/person08_running_d2.avi 4\n',
#        'running/person08_running_d3.avi 4\n',
#        'running/person08_running_d4.avi 4\n',
#        'running/person09_running_d1.avi 4\n',
#        'running/person09_running_d2.avi 4\n',
#        'running/person09_running_d3.avi 4\n',
#        'running/person09_running_d4.avi 4\n',
#        'running/person10_running_d1.avi 4\n',
#        'running/person10_running_d2.avi 4\n',
#        'running/person10_running_d3.avi 4\n',
#        'running/person10_running_d4.avi 4\n',
#        'running/person11_running_d1.avi 4\n',
#        'running/person11_running_d2.avi 4\n',
#        'running/person11_running_d3.avi 4\n',
#        'running/person11_running_d4.avi 4\n',
#        'running/person12_running_d1.avi 4\n',
#        'running/person12_running_d2.avi 4\n',
#        'running/person12_running_d3.avi 4\n',
#        'running/person12_running_d4.avi 4\n',
#        'running/person13_running_d1.avi 4\n',
#        'running/person13_running_d2.avi 4\n',
#        'running/person13_running_d3.avi 4\n',
#        'running/person13_running_d4.avi 4\n',
#        'running/person14_running_d1.avi 4\n',
#        'running/person14_running_d2.avi 4\n',
#        'running/person14_running_d3.avi 4\n',
#        'running/person14_running_d4.avi 4\n',
#        'running/person15_running_d1.avi 4\n',
#        'running/person15_running_d2.avi 4\n',
#        'running/person15_running_d3.avi 4\n',
#        'running/person15_running_d4.avi 4\n',
#        'running/person16_running_d1.avi 4\n',
#        'running/person16_running_d2.avi 4\n',
#        'running/person16_running_d3.avi 4\n',
#        'running/person16_running_d4.avi 4\n',
#        'running/person17_running_d1.avi 4\n',
#        'running/person17_running_d2.avi 4\n',
#        'running/person17_running_d3.avi 4\n',
#        'running/person17_running_d4.avi 4\n',
#        'running/person18_running_d1.avi 4\n',
#        'running/person18_running_d2.avi 4\n',
#        'running/person18_running_d3.avi 4\n',
#        'running/person18_running_d4.avi 4\n',
#        'running/person19_running_d1.avi 4\n',
#        'running/person19_running_d2.avi 4\n',
#        'running/person19_running_d3.avi 4\n',
#        'running/person19_running_d4.avi 4\n',
#        'running/person20_running_d1.avi 4\n',
#        'running/person20_running_d2.avi 4\n',
#        'running/person20_running_d3.avi 4\n',
#        'running/person20_running_d4.avi 4\n',
#        'running/person21_running_d1.avi 4\n',
#        'running/person21_running_d2.avi 4\n',
#        'running/person21_running_d3.avi 4\n',
#        'running/person21_running_d4.avi 4\n',
#        'running/person22_running_d1.avi 4\n',
#        'running/person22_running_d2.avi 4\n',
#        'running/person22_running_d3.avi 4\n',
#        'running/person22_running_d4.avi 4\n',
#        'running/person23_running_d1.avi 4\n',
#        'running/person23_running_d2.avi 4\n',
#        'running/person23_running_d3.avi 4\n',
#        'running/person23_running_d4.avi 4\n',
#        'running/person24_running_d1.avi 4\n',
#        'running/person24_running_d2.avi 4\n',
#        'running/person24_running_d3.avi 4\n',
#        'running/person24_running_d4.avi 4\n',
#        'running/person25_running_d1.avi 4\n',
#        'running/person25_running_d2.avi 4\n',
#        'running/person25_running_d3.avi 4\n',
#        'running/person25_running_d4.avi 4\n',
#        'walking/person01_walking_d1.avi 5\n',
#        'walking/person01_walking_d2.avi 5\n',
#        'walking/person01_walking_d3.avi 5\n',
#        'walking/person01_walking_d4.avi 5\n',
#        'walking/person02_walking_d1.avi 5\n',
#        'walking/person02_walking_d2.avi 5\n',
#        'walking/person02_walking_d3.avi 5\n',
#        'walking/person02_walking_d4.avi 5\n',
#        'walking/person03_walking_d1.avi 5\n',
#        'walking/person03_walking_d2.avi 5\n',
#        'walking/person03_walking_d3.avi 5\n',
#        'walking/person03_walking_d4.avi 5\n',
#        'walking/person04_walking_d1.avi 5\n',
#        'walking/person04_walking_d2.avi 5\n',
#        'walking/person04_walking_d3.avi 5\n',
#        'walking/person04_walking_d4.avi 5\n',
#        'walking/person05_walking_d1.avi 5\n',
#        'walking/person05_walking_d2.avi 5\n',
#        'walking/person05_walking_d3.avi 5\n',
#        'walking/person05_walking_d4.avi 5\n',
#        'walking/person06_walking_d1.avi 5\n',
#        'walking/person06_walking_d2.avi 5\n',
#        'walking/person06_walking_d3.avi 5\n',
#        'walking/person06_walking_d4.avi 5\n',
#        'walking/person07_walking_d1.avi 5\n',
#        'walking/person07_walking_d2.avi 5\n',
#        'walking/person07_walking_d3.avi 5\n',
#        'walking/person07_walking_d4.avi 5\n',
#        'walking/person08_walking_d1.avi 5\n',
#        'walking/person08_walking_d2.avi 5\n',
#        'walking/person08_walking_d3.avi 5\n',
#        'walking/person08_walking_d4.avi 5\n',
#        'walking/person09_walking_d1.avi 5\n',
#        'walking/person09_walking_d2.avi 5\n',
#        'walking/person09_walking_d3.avi 5\n',
#        'walking/person09_walking_d4.avi 5\n',
#        'walking/person10_walking_d1.avi 5\n',
#        'walking/person10_walking_d2.avi 5\n',
#        'walking/person10_walking_d3.avi 5\n',
#        'walking/person10_walking_d4.avi 5\n',
#        'walking/person11_walking_d1.avi 5\n',
#        'walking/person11_walking_d2.avi 5\n',
#        'walking/person11_walking_d3.avi 5\n',
#        'walking/person11_walking_d4.avi 5\n',
#        'walking/person12_walking_d1.avi 5\n',
#        'walking/person12_walking_d2.avi 5\n',
#        'walking/person12_walking_d3.avi 5\n',
#        'walking/person12_walking_d4.avi 5\n',
#        'walking/person13_walking_d1.avi 5\n',
#        'walking/person13_walking_d2.avi 5\n',
#        'walking/person13_walking_d3.avi 5\n',
#        'walking/person13_walking_d4.avi 5\n',
#        'walking/person14_walking_d1.avi 5\n',
#        'walking/person14_walking_d2.avi 5\n',
#        'walking/person14_walking_d3.avi 5\n',
#        'walking/person14_walking_d4.avi 5\n',
#        'walking/person15_walking_d1.avi 5\n',
#        'walking/person15_walking_d2.avi 5\n',
#        'walking/person15_walking_d3.avi 5\n',
#        'walking/person15_walking_d4.avi 5\n',
#        'walking/person16_walking_d1.avi 5\n',
#        'walking/person16_walking_d2.avi 5\n',
#        'walking/person16_walking_d3.avi 5\n',
#        'walking/person16_walking_d4.avi 5\n',
#        'walking/person17_walking_d1.avi 5\n',
#        'walking/person17_walking_d2.avi 5\n',
#        'walking/person17_walking_d3.avi 5\n',
#        'walking/person17_walking_d4.avi 5\n',
#        'walking/person18_walking_d1.avi 5\n',
#        'walking/person18_walking_d2.avi 5\n',
#        'walking/person18_walking_d3.avi 5\n',
#        'walking/person18_walking_d4.avi 5\n',
#        'walking/person19_walking_d1.avi 5\n',
#        'walking/person19_walking_d2.avi 5\n',
#        'walking/person19_walking_d3.avi 5\n',
#        'walking/person19_walking_d4.avi 5\n',
#        'walking/person20_walking_d1.avi 5\n',
#        'walking/person20_walking_d2.avi 5\n',
#        'walking/person20_walking_d3.avi 5\n',
#        'walking/person20_walking_d4.avi 5\n',
#        'walking/person21_walking_d1.avi 5\n',
#        'walking/person21_walking_d2.avi 5\n',
#        'walking/person21_walking_d3.avi 5\n',
#        'walking/person21_walking_d4.avi 5\n',
#        'walking/person22_walking_d1.avi 5\n',
#        'walking/person22_walking_d2.avi 5\n',
#        'walking/person22_walking_d3.avi 5\n',
#        'walking/person22_walking_d4.avi 5\n',
#        'walking/person23_walking_d1.avi 5\n',
#        'walking/person23_walking_d2.avi 5\n',
#        'walking/person23_walking_d3.avi 5\n',
#        'walking/person23_walking_d4.avi 5\n',
#        'walking/person24_walking_d1.avi 5\n',
#        'walking/person24_walking_d2.avi 5\n',
#        'walking/person24_walking_d3.avi 5\n',
#        'walking/person24_walking_d4.avi 5\n',
#        'walking/person25_walking_d1.avi 5\n',
#        'walking/person25_walking_d2.avi 5\n',
#        'walking/person25_walking_d3.avi 5\n',
#        'walking/person25_walking_d4.avi 5'], dtype='<U44')

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(data, label, test_size=0.2, stratify=label, random_state=77)

print("train, val shape : ", X_train.shape, X_val.shape)
print("y_val : ", y_val[:10])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 from sklearn.model_selection import train_test_split
# ----> 3 X_train, X_val, y_train, y_val = train_test_split(data, label, test_size=0.2, stratify=label, random_state=77)
#       5 print("train, val shape : ", X_train.shape, X_val.shape)
#       6 print("y_val : ", y_val[:10])
#
# File /data/ahngeo11/anaconda3/envs/svt/lib/python3.10/site-packages/sklearn/model_selection/_split.py:2469, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2465         CVClass = ShuffleSplit
#    2467     cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
# -> 2469     train, test = next(cv.split(X=arrays[0], y=stratify))
#    2471 return list(
#    2472     chain.from_iterable(
#    2473         (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
#    2474     )
#    2475 )
#
# File /data/ahngeo11/anaconda3/envs/svt/lib/python3.10/site-packages/sklearn/model_selection/_split.py:1622, in BaseShuffleSplit.split(self, X, y, groups)
#    1592 """Generate indices to split data into training and test set.
#    1593
#    1594 Parameters
#    (...)
#    1619 to an integer.
#    1620 """
#    1621 X, y, groups = indexable(X, y, groups)
# -> 1622 for train, test in self._iter_indices(X, y, groups):
#    1623     yield train, test
#
# File /data/ahngeo11/anaconda3/envs/svt/lib/python3.10/site-packages/sklearn/model_selection/_split.py:1968, in StratifiedShuffleSplit._iter_indices(self, X, y, groups)
#    1966 class_counts = np.bincount(y_indices)
#    1967 if np.min(class_counts) < 2:
# -> 1968     raise ValueError(
#    1969         "The least populated class in y has only 1"
#    1970         " member, which is too few. The minimum"
#    1971         " number of groups for any class cannot"
#    1972         " be less than 2."
#    1973     )
#    1975 if n_train < n_classes:
#    1976     raise ValueError(
#    1977         "The train_size = %d should be greater or "
#    1978         "equal to the number of classes = %d" % (n_train, n_classes)
#    1979     )
#
# ValueError: The least populated class in y has only 1 member, which is too few. The minimum number of groups for any class cannot be less than 2.
